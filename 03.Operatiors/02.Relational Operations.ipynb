# %%
# Relational Operators Are: <,>,==,!=,<=,>=

# %%
a=20
b=40
a,b
# Out:
# (20, 40)

# %%
a>b
# Out:
# False

# %%
a<b
# Out:
# True

# %%
a==b
# Out:
# False

# %%
a!=b
# Out:
# True

# %%
a>=b
# Out:
# False

# %%
a<=b
# Out:
# True
