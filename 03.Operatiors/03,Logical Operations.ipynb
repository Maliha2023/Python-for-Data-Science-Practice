# %%
# Logical operators: &, |

# %%
a=True
b=False
a,b
# Out:
# (True, False)

# %%
a&b
# Out:
# False

# %%
a&a
# Out:
# True

# %%
b&a
# Out:
# False

# %%
b&b
# Out:
# False

# %%
a|b
# Out:
# True

# %%
a|a
# Out:
# True
